# %% [markdown]
# # Welcome to PYNQ Audio
# This notebook shows the basic recording and playback features of the AUP-ZU3.
# It uses the audio jack `HP+MIC` to play back recordings; it can take inputs from
# the microphone on `HP+MIC` or `LINE_IN`. Pre-recorded audio sample can also be taken
# as input. Moreover, visualization with matplotlib is shown.
#
# The notebook works with **both** builds of the AIC3104 interface. It reads the
# design's version register (`REG_VER`) and automatically uses the matching
# capture/playback path:
#
# * **version 1 &rarr; polling build** (`aic3104_poll.sv`): the CPU moves one
#   sample at a time through the RX/TX FIFOs.
# * **version 2 &rarr; DMA build** (`aic3104_dma.sv`): the `axi_dma_writer`/`axi_dma_reader`
#   engines stream whole DDR buffers at hardware rate.
#
# ## Create new audio object

# %%
# !pip install pynq
# Out:
# Requirement already satisfied: pynq in /usr/local/lib/python3.12/dist-packages (3.1.2)
# Requirement already satisfied: pynqmetadata in /usr/local/lib/python3.12/dist-packages (from pynq) (0.1.9)
# Requirement already satisfied: pynqutils in /usr/local/lib/python3.12/dist-packages (from pynq) (0.1.2)
# Requirement already satisfied: setuptools>=24.2.0 in /usr/local/lib/python3.12/dist-packages (from pynq) (75.2.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from pynq) (2.1.1)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.12/dist-packages (from pynq) (1.26.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from pynq) (1.6.0)
# Requirement already satisfied: grpcio==1.64.0 in /usr/local/lib/python3.12/dist-packages (from pynq) (1.64.0)
# Requirement already satisfied: grpcio-tools==1.64.0 in /usr/local/lib/python3.12/dist-packages (from pynq) (1.64.0)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in /usr/local/lib/python3.12/dist-packages (from grpcio-tools==1.64.0->pynq) (5.29.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->pynq) (3.0)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from pynqmetadata->pynq) (4.26.0)
# Requirement already satisfied: pydantic==1.9.1 in /usr/local/lib/python3.12/dist-packages (from pynqmetadata->pynq) (1.9.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from pynqmetadata->pynq) (7.34.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from pydantic==1.9.1->pynqmetadata->pynq) (4.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pynqutils->pynq) (4.67.3)
# Requirement already satisfied: python-magic>=0.4.25 in /usr/local/lib/python3.12/dist-packages (from pynqutils->pynq) (0.4.27)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->pynqmetadata->pynq) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->pynqmetadata->pynq) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->pynqmetadata->pynq) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->pynqmetadata->pynq) (2026.6.3)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython->pynqmetadata->pynq) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->pynqmetadata->pynq) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->pynqmetadata->pynq) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->pynqmetadata->pynq) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->pynqmetadata->pynq) (3.0.53)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->pynqmetadata->pynq) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->pynqmetadata->pynq) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->pynqmetadata->pynq) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->pynqmetadata->pynq) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->pynqmetadata->pynq) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->pynqmetadata->pynq) (0.7.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->pynqmetadata->pynq) (0.8.2)

# %%
# !drive.mount('/content/drive')
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `'/content/drive''
# /bin/bash: -c: line 1: `drive.mount('/content/drive')'

# %%
# !git clone --recursive https://github.com/RuimingJin/theFPGAprogrammingHANDBOOK3rd.git
# Out:
# Cloning into 'theFPGAprogrammingHANDBOOK3rd'...
# remote: Enumerating objects: 1415, done.
# remote: Counting objects: 100% (1415/1415), done.
# remote: Compressing objects: 100% (631/631), done.
# remote: Total 1415 (delta 566), reused 1415 (delta 566), pack-reused 0 (from 0)
# Receiving objects: 100% (1415/1415), 30.81 MiB | 25.02 MiB/s, done.
# Resolving deltas: 100% (566/566), done.

# %%
os.chdir('/content')

# %%
# !ls
# Out:
# sample_data		       The-FPGA-Programming-Handbook-Third-Edition
# theFPGAprogrammingHANDBOOK3rd

# %%
import os
#os.chdir('theFPGAprogrammingHANDBOOK3rd/CH09/Jupyter')
from pynq import Overlay, allocate
import time
from aic3104 import AIC3104
import numpy as np
from scipy.io import wavfile
import asyncio
import wave

# 1. Load the Overlay
ol = Overlay("hw_wrapper.bit")

# 2. Check IP Dictionary
print("Available IPs:", ol.ip_dict.keys())

# release audio reset
rst = ol.audio.axi_gpio_0.channel1
rst.write(0x1, 0x1)

codec = AIC3104(ol.audio.axi_iic_0)
print("on the bus:", codec.scan())          # should now list 0x18
codec.reset_controller()            # clear a wedged AXI-IIC core if needed
print("on the bus:", codec.scan())          # should now list 0x18
codec.init(mclk_hz=12_288_000, fs=48000, word_len=16)     # set mclk_hz to YOUR design's MCLK
codec.select_microphone()
print(codec.dump())

# Locate the AIC3104 audio control IP. The polling and DMA builds package
# different wrappers (e.g. aic3104_wrapper_0 vs aic3104_dma_wrapper_0), but both
# names contain "aic3104", so find it generically instead of hard-coding one.
aic_name = next(n.split('/')[-1] for n in ol.ip_dict if 'aic3104' in n.lower())
aic = getattr(ol.audio, aic_name)
print("Audio control IP:", aic_name)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2648/2101403163.py in <cell line: 0>()
#      10
#      11 # 1. Load the Overlay
# ---> 12 ol = Overlay("hw_wrapper.bit")
#      13
#      14 # 2. Check IP Dictionary
#
# /usr/local/lib/python3.12/dist-packages/pynq/overlay.py in __init__(self, bitfile_name, dtbo, download, ignore_version, device, gen_cache)
#     316
#     317         """
# --> 318         super().__init__(bitfile_name, dtbo, partial=False, device=device)
#     319
#     320         self._register_drivers()
#
# /usr/local/lib/python3.12/dist-packages/pynq/bitstream.py in __init__(self, bitfile_name, dtbo, partial, device)
#      86             from .pl_server.device import Device
#      87
# ---> 88             device = Device.active_device
#      89         self.device = device
#      90
#
# /usr/local/lib/python3.12/dist-packages/pynq/pl_server/device.py in active_device(cls)
#      69         if not hasattr(cls, "_active_device"):
#      70             if len(cls.devices) == 0:
# ---> 71                 raise RuntimeError("No Devices Found")
#      72             cls._active_device = cls.devices[0]
#      73         return cls._active_device
#
# RuntimeError: No Devices Found

# %%
# ---------------------------------------------------------------------------
# Register maps for BOTH builds of the AIC3104 interface.
#
# REG_DEV / REG_VER / REG_INT / REG_CFG sit at the SAME addresses in both
# builds, so we always read REG_VER first and then pick the right register set:
#     version 1 -> polling build (aic3104_poll): one sample per AXI access
#     version 2 -> DMA build      (aic3104_dma):  buffer/address DMA
# ---------------------------------------------------------------------------

# -- common (identical in both builds) --
REG_DEV = 0x200
REG_VER = 0x204
REG_INT = 0x208
REG_CFG = 0x20c           # [2:0] = RX capture sample delay (MCLK ticks); both builds

# -- DMA build (version 2) --
REG_TX_ADDR_LO    = 0x0
REG_TX_ADDR_HI    = 0x4
REG_TX_BYTES      = 0x8
REG_TX_START      = 0xc
REG_TX_BYTES_READ = 0x10
REG_TX_STAT       = 0x14
REG_RX_ADDR_LO    = 0x100
REG_RX_ADDR_HI    = 0x104
REG_RX_BYTES      = 0x108
REG_RX_START      = 0x10c
REG_RX_BYTES_READ = 0x110
REG_RX_STAT       = 0x114
DONE_BIT          = 1 << 31
UNDERFLOW_BIT     = 1 << 3         # REG_TX_STAT[3] = playback underflow (TX starved)

# -- polling build (version 1) --
P_TX_CTRL  = 0x0
P_TX_COUNT = 0x4
P_TX_DATA  = 0x8
P_TX_STAT  = 0xc          # bit0 = tx_full
P_RX_CTRL  = 0x110
P_RX_COUNT = 0x114
P_RX_DATA  = 0x118
P_RX_STAT  = 0x11c        # bit0 = rx_empty

# ---- Identify the build by reading the version register --------------------
device  = aic.read(REG_DEV)
version = aic.read(REG_VER)
dev_str = device.to_bytes(4, "big").decode("ascii", "replace")
IS_DMA  = (version == 2)
mode    = "DMA" if IS_DMA else "polling"
print(f"I2S Device = {dev_str!r} (0x{device:08x}), Version = {version} -> {mode} build")

# ===========================================================================
#  Capture (record) -- fill a buffer of packed 32-bit L/R samples
# ===========================================================================
def dma_capture(buf):
    """version 2: hand the engine a buffer address + length, then wait for done.

    REG_RX_STAT[31] (done) is *sticky*: it stays set from the previous capture
    until the next START clears it. So we must wait for it to DROP (this transfer
    accepted) and then RISE (this transfer finished). Polling only for "set"
    falls through instantly on a re-run / after the tuning sweep and returns a
    stale (empty) buffer -- which looks like 'no data captured'."""
    aic.write(REG_RX_ADDR_LO, buf.device_address & 0xFFFFFFFF)
    aic.write(REG_RX_ADDR_HI, buf.device_address >> 32)   # addr can exceed 32 bits
    aic.write(REG_RX_BYTES,   buf.nbytes)
    aic.write(REG_RX_START,   1)                          # cfg_start pulse
    while aic.read(REG_RX_STAT) & DONE_BIT:               # stale done clears
        pass
    while not (aic.read(REG_RX_STAT) & DONE_BIT):         # this capture done
        pass
    # The S2MM engine wrote straight to DRAM over the (non-coherent) HP port.
    # Drop any stale cache lines for this buffer so the CPU reads what the DMA
    # actually wrote; skipping this is a classic source of crackle/garbage.
    buf.invalidate()
    return aic.read(REG_RX_BYTES_READ)

def poll_capture(buf):
    """version 1: read one sample at a time out of the RX FIFO.

    The CPU cannot poll a 48 kHz FIFO from Python without falling behind, so
    samples are dropped and the recording is a slow, lossy grab -- exactly the
    limitation the DMA build removes. We wait for rx_empty to clear before each
    read so we never latch a stale word."""
    n = buf.shape[0]
    aic.write(P_RX_CTRL, 1)                            # enable RX capture
    for i in range(n):
        while aic.read(P_RX_STAT) & 1:                 # wait while rx_empty
            pass
        buf[i] = aic.read(P_RX_DATA)                   # reading pops one sample
    aic.write(P_RX_CTRL, 0)                            # stop capture
    return n * 4

def audio_capture(buf):
    """Record into buf using whichever path the loaded build provides."""
    return dma_capture(buf) if IS_DMA else poll_capture(buf)

# ===========================================================================
#  RX capture sample-timing alignment  (BOTH builds expose REG_CFG)
#
#  The codec drives its captured data (DOUT) back to the FPGA delayed by the
#  BCLK round-trip + the codec's output delay. That delay is board-specific, so
#  the exact instant the FPGA should sample DOUT cannot be fixed in the RTL (or
#  in simulation). REG_CFG[2:0] (rx_dly) slides the whole sampling grid later in
#  1-MCLK steps; a wrong value samples each bit before it has settled, which
#  drops the sample MSB and folds the sign at every zero crossing -- heard as
#  low-amplitude noise / static. Sweep it once on hardware (with a signal
#  playing into the selected input) and keep the cleanest value. The polling and
#  DMA builds share this register and the same deserializer, so both are tuned
#  the same way.
# ===========================================================================
def set_rx_delay(d):
    """Set the RX sample delay (0..7 MCLK ticks) in REG_CFG[2:0]. Both builds."""
    aic.write(REG_CFG, d & 0x7)

def tune_rx_delay(seconds=0.25, verbose=True):
    """Sweep rx_dly 0..7, capture a short buffer at each, and select the value
    with the smoothest waveform (lowest mean sample-to-sample step). Feed a
    steady tone or speech into the active input while running this. Returns the
    chosen delay and leaves it programmed. Works on both builds."""
    # Polling capture is slow from Python, so use a small buffer there.
    n = max(1024, int(seconds * SAMPLE_RATE)) if IS_DMA else 2048
    b = allocate(shape=(n,), dtype=np.uint32)
    best_d, best_score = 0, None
    for d in range(8):
        set_rx_delay(d)
        audio_capture(b)
        left  = (b & 0xFFFF).astype(np.uint16).view(np.int16).astype(np.int32)
        peak  = int(np.abs(left).max())
        score = float(np.abs(np.diff(left)).mean())   # roughness: low = clean
        if verbose:
            print(f"  rx_dly={d}: peak={peak:6d}  roughness={score:9.1f}")
        if best_score is None or score < best_score:
            best_score, best_d = score, d
    b.freebuffer()
    set_rx_delay(best_d)
    print(f"Selected rx_dly={best_d} (roughness={best_score:.1f}). "
          f"Pin it with set_rx_delay({best_d}) to skip tuning next time.")
    return best_d

# ===========================================================================
#  Playback -- stream a buffer of packed 32-bit L/R samples out the codec
# ===========================================================================
def dma_play(buf):
    """version 2: hand the reader (MM2S) a buffer address + length."""
    buf.flush()                                           # push any CPU writes to DRAM first
    aic.write(REG_TX_ADDR_LO, buf.device_address & 0xFFFFFFFF)
    aic.write(REG_TX_ADDR_HI, buf.device_address >> 32)
    aic.write(REG_TX_BYTES,   buf.nbytes)
    aic.write(REG_TX_START,   1)                          # cfg_start pulse
    # done (bit 31) is sticky from the previous run: wait for it to clear (the
    # reader took the new transfer) and then set again (this transfer finished).
    while aic.read(REG_TX_STAT) & DONE_BIT:               # stale done clears
        pass
    while not (aic.read(REG_TX_STAT) & DONE_BIT):         # new transfer done
        pass
    if aic.read(REG_TX_STAT) & UNDERFLOW_BIT:
        print("WARNING: playback underflow - reader could not keep the TX FIFO fed")
    return aic.read(REG_TX_BYTES_READ)

def poll_play(buf):
    """version 1: push one sample at a time into the TX FIFO, throttling on
    tx_full. As with poll_capture, Python can't sustain 48 kHz, so playback
    will underflow (audible gaps) -- the DMA build is what fixes this."""
    n = buf.shape[0]
    for i in range(n):
        while aic.read(P_TX_STAT) & 1:                 # wait while tx_full
            pass
        aic.write(P_TX_DATA, int(buf[i]))
    return n * 4

def audio_playback(buf):
    """Play buf out the codec using whichever path the loaded build provides."""
    return dma_play(buf) if IS_DMA else poll_play(buf)

# %%
print("Starting Capture")
# The DMA build records in real time; the polling build can only manage a short,
# lossy grab from Python, so keep the duration small when version == 1.
SAMPLE_RATE = 48000          # set this to your I2S/codec rate (44100, 48000, ...)
TIME = 5 if IS_DMA else 1    # seconds  (polling is slow -- keep it short)

# The instant to sample the codec's DOUT is board-specific (BCLK round-trip +
# codec output delay), so find it once on hardware -- both builds expose the
# REG_CFG delay. Play a tone or speak into the active input while this runs.
# Once you know your board's value, replace this with set_rx_delay(<n>).
tune_rx_delay()

N = TIME * SAMPLE_RATE
buf = allocate(shape=(N,), dtype=np.uint32)   # default: non-cacheable -> HP port

read_bytes = audio_capture(buf)
print(f"Capture Complete! ({read_bytes} bytes, {read_bytes // 4} frames)")

# --- Unpack the 32-bit word into two signed 16-bit samples ---
# The hardware packs each beat as {right[15:0], left[15:0]} -> bits[31:16]=RIGHT,
# bits[15:0]=LEFT (see rx_fifo din = {rx_din[63:48], rx_din[31:16]} in
# aic3104_dma.sv, where rx_din[31:0] is the WS-low LEFT channel). So the LOW
# half is LEFT and the HIGH half is RIGHT -- do not swap these.
left  = (buf & 0xFFFF).astype(np.uint16).view(np.int16)
right = (buf >> 16).astype(np.uint16).view(np.int16)

# --- Interleave L R L R for a stereo WAV ---
stereo = np.empty(N * 2, dtype=np.int16)
stereo[0::2] = left
stereo[1::2] = right

# --- Write the WAV ---
with wave.open("capture.wav", "wb") as w:
    w.setnchannels(2)
    w.setsampwidth(2)          # 2 bytes = 16 bits
    w.setframerate(SAMPLE_RATE)
    w.writeframes(stereo.tobytes())

# %% [markdown]
# ## Play back the capture
# Stream the captured buffer back out through the codec. `audio_playback()` picks
# the path that matches the build detected from `REG_VER`:
#
# * **DMA build (version 2):** the `axi_dma_reader` (MM2S) engine walks the DDR
#   buffer and feeds the I2S TX FIFO, which the DAC drains one packed L/R sample
#   per 48&nbsp;kHz frame.
# * **Polling build (version 1):** the CPU pushes each sample into the TX FIFO,
#   throttling on `tx_full` (slow from Python, so expect underflow gaps).
#
# Audio comes out of the **LINE OUT** jack (green, J4). The capture buffer `buf`
# is already in the exact 32-bit packing the TX path expects
# (`bits[31:16]=right`, `bits[15:0]=left` &mdash; the same words the capture path
# produced), so we replay it **verbatim**: no WAV round-trip and no L/R re-packing.
#
# > **Note on the DMA done bit.** `REG_TX_STAT[31]` (done) is *sticky*: it stays
# > set from the previous playback until the next `START` clears it. So the DMA
# > path waits for it to **drop** (the reader accepted the new transfer) and then
# > **rise** again (this transfer finished). Polling only for "set" would fall
# > through instantly on a re-run, reading back a stale completion.

# %%
# --- Playback (works for both builds) ---
# Replay the just-captured buffer back out through the codec. `buf` already holds
# the 32-bit packed L/R words the capture produced, so we stream it back verbatim
# -- no WAV round-trip, no re-packing, so L/R can't get swapped. audio_playback()
# dispatches to the DMA reader (version 2) or the polling TX FIFO loop (version 1)
# based on the version we read earlier. The DAC drives LINE OUT (green jack J4).

print(f"Playing {N/SAMPLE_RATE:.2f} s ({N} frames) out LINE OUT via the {mode} path ...")
played = audio_playback(buf)
print(f"Played {played} bytes ({played // 4} frames); playback complete!")

# %% [markdown]
# ## Play in notebook
# Since the samples are in 24-bit PCM format,
# users can play the audio directly in notebook.

# %%
from IPython.display import Audio as IPAudio
IPAudio("capture.wav")

# %% [markdown]
# ## Plotting PCM data
#
# Users can display the audio data in notebook:
#
# 1. Plot the audio signal's amplitude over time.
# 2. Plot the spectrogram of the audio signal.
#
# The next cell reads the saved audio file and processes it into a `numpy` array.
# Note that if the audio sample width is not standard, additional processing
# is required. In the following example, the `sample_width` is read from the
# wave file itself (24-bit dual-channel PCM audio, where `sample_width` is 3 bytes).

# %%
# %matplotlib inline
import wave
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.fftpack import fft

wav_path = "capture.wav"
with wave.open(wav_path, 'r') as wav_file:
    raw_frames = wav_file.readframes(-1)
    num_frames = wav_file.getnframes()
    num_channels = wav_file.getnchannels()
    sample_rate = wav_file.getframerate()
    sample_width = wav_file.getsampwidth()

temp_buffer = np.empty((num_frames, num_channels, 4), dtype=np.uint8)
raw_bytes = np.frombuffer(raw_frames, dtype=np.uint8)
temp_buffer[:, :, :sample_width] = raw_bytes.reshape(-1, num_channels,
                                                    sample_width)
temp_buffer[:, :, sample_width:] = \
    (temp_buffer[:, :, sample_width-1:sample_width] >> 7) * 255
frames = temp_buffer.view('<i4').reshape(temp_buffer.shape[:-1])

# %% [markdown]
# ### 1. Amplitude over time

# %%
for channel_index in range(num_channels):
    plt.figure(num=None, figsize=(15, 3))
    plt.title('Audio in Time Domain (Channel {})'.format(channel_index))
    plt.xlabel('Time in s')
    plt.ylabel('Amplitude')
    time_axis = np.arange(0, num_frames/sample_rate, 1/sample_rate)
    plt.plot(time_axis, frames[:, channel_index])
    plt.show()

# %% [markdown]
# ### 2. Frequency spectrum

# %%
for channel_index in range(num_channels):
    plt.figure(num=None, figsize=(15, 3))
    plt.title('Audio in Frequency Demain (Channel {})'.format(channel_index))
    plt.xlabel('Frequency in Hz')
    plt.ylabel('Magnitude')
    temp = fft(frames[:, channel_index])
    yf = temp[1:len(temp)//2]
    xf = np.linspace(0.0, sample_rate/2, len(yf))
    plt.plot(xf, abs(yf))
    plt.show()

# %% [markdown]
# ### 3. Frequency spectrum over time
# Use the `classic` plot style for better display.

# %%
for channel_index in range(num_channels):
    np.seterr(divide='ignore', invalid='ignore')
    matplotlib.style.use("classic")
    plt.figure(num=None, figsize=(15, 3))
    plt.title('Signal Spectogram (Channel {})'.format(channel_index))
    plt.xlabel('Time in s')
    plt.ylabel('Frequency in Hz')
    plt.specgram(frames[:, channel_index], Fs=sample_rate)

# %% [markdown]
# Copyright (c) 2022 Xilinx, Inc
# <br>
# Copyright (C) 2022-2025 Advanced Micro Devices, Inc.
# <br>
# SPDX-License-Identifier: BSD-3-Clause
